# %%
import pandas as pd
import os
import requests
from io import StringIO
from datetime import datetime

# %%
state_abv = {
    '2': 'AK',
    '1': 'AL',
    '5': 'AR',
    '4': 'AZ',
    '6': 'CA',
    '8': 'CO',
    '9': 'CT',
    '11': 'DC',
    '10': 'DE',
    '12': 'FL',
    '13': 'GA',
    '15': 'HI',
    '19': 'IA',
    '16': 'ID',
    '17': 'IL',
    '18': 'IN',
    '20': 'KS',
    '21': 'KY',
    '22': 'LA',
    '25': 'MA',
    '24': 'MD',
    '23': 'ME',
    '26': 'MI',
    '27': 'MN',
    '29': 'MO',
    '28': 'MS',
    '30': 'MT',
    '37': 'NC',
    '38': 'ND',
    '31': 'NE',
    '33': 'NH',
    '34': 'NJ',
    '35': 'NM',
    '32': 'NV',
    '36': 'NY',
    '39': 'OH',
    '40': 'OK',
    '41': 'OR',
    '42': 'PA',
    '44': 'RI',
    '45': 'SC',
    '46': 'SD',
    '47': 'TN',
    '48': 'TX',
    '49': 'UT',
    '51': 'VA',
    '50': 'VT',
    '53': 'WA',
    '55': 'WI',
    '54': 'WV',
    '56': 'WY'}

# %%
test_state_abv = {
    '2': 'AK',
    '1': 'AL',
    '5': 'AR',
    '4': 'AZ'}

# %%
comstock_buildings = ['quickservicerestaurant',
                      'fullservicerestaurant',
                      'smalloffice',
                      'mediumoffice',
                      'largeoffice',
                      'warehouse',
                      'smallhotel',
                      'largehotel',
                      'outpatient',
                      'hospital',
                      'secondaryschool',
                      'primaryschool',
                      'retailstandalone',
                      'retailstripmall']

# %%
test_comstock_buildings = ['smalloffice']

# %%
#upgrades = ['17','18']
#upgrades = ['5','6','7','8','9','10','15']
test_upgrades = ['17']

# %%
columns=[
    'upgrade',
    'in.comstock_building_type',
    'in.state',
    'applicability',
    'in.sqft',
    'in.year_built',
    'in.energy_code_followed_during_last_ext_lighting_replacement',
    'in.energy_code_followed_during_last_hvac_replacement',
    'in.energy_code_followed_during_last_int_equipment_replacement',
    'in.energy_code_followed_during_last_roof_replacement',
    'in.energy_code_followed_during_last_svc_water_htg_replacement',
    'in.energy_code_followed_during_last_walls_replacement',
    'in.energy_code_followed_during_original_building_construction',
    'calc.percent_savings.electricity.total.energy_consumption_intensity..percent',
    'calc.percent_savings.electricity.total.energy_consumption..percent',
    'calc.percent_savings.natural_gas.total.energy_consumption_intensity..percent',
    'calc.percent_savings.natural_gas.total.energy_consumption..percent',
    'calc.percent_savings.site_energy.total.energy_consumption..percent',
    'calc.percent_savings.site_energy.total.energy_consumption_intensity..percent'
]

# %%
base_url = "https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state={STATE}/csv/{STATE}_upgrade{up}_metadata_and_annual_results.csv"
#https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=CO/csv/CO_upgrade18_metadata_and_annual_results.csv

# %%
# loop over upgrades
for upgrade in test_upgrades:
    UP = str(upgrade)
    up = f"{int(upgrade):02}"  # Convert string to int and format with leading zero

    # Loop through each state abbreviation
    for state in state_abv.values():
                   
        # Construct the URL for the current state
        url = base_url.format(up=up, STATE=state.upper())
        print(f"url: {url}")
        try:
            # Make a GET request to fetch the CSV content
            response = requests.get(url)
            if response.status_code == 200:
                print(f"DOWNLOADING upgrade: {up}, state: {state}")
                # Convert the CSV content to a DataFrame
                csv_content = StringIO(response.content.decode('utf-8'))
                df = pd.read_csv(csv_content, low_memory=False)

                # Group by 'in.comstock_building_type'
                grouped = df.groupby('in.comstock_building_type')

                # Iterate over each group, filter columns that match the defined columns, and save as separate files
                for building_type, group in grouped:
                    # Filter columns that match the defined columns
                    filtered_df = group[columns].dropna(how='all')  # Optionally, remove rows where all selected columns are NaN
                    
                    # Check and create directory if needed
                    directory = f'annual_data/{up}/{building_type}/{state.upper()}'
                    os.makedirs(directory, exist_ok=True)  # This will create the directory if it doesn't exist

                    # Define the base file path
                    base_file_path = f'{directory}/{state.upper()}_df.csv'

                    # to avoid overwriting existing files, check if the file exists
                    if os.path.exists(base_file_path):
                        # Create a unique file name, e.g., by appending a timestamp
                        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
                        file_path = f'{directory}/{state.upper()}_df_{timestamp}.csv'
                    else:
                        file_path = base_file_path

                    # Save filtered DataFrame to CSV (assuming 'filtered_df' is your DataFrame)
                    filtered_df.to_csv(file_path, index=False)

                    print(f'Saved {file_path}')

            else:
                print(f"Failed to download data for {state.upper()}: HTTP {response.status_code}")
        except Exception as e:
            print(f"Error downloading data for {state.upper()}: {e}")
# Out:
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=AK/csv/AK_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: AK
# Saved annual_data/17/FullServiceRestaurant/AK/AK_df.csv
# Saved annual_data/17/Hospital/AK/AK_df.csv
# Saved annual_data/17/LargeHotel/AK/AK_df.csv
# Saved annual_data/17/LargeOffice/AK/AK_df.csv
# Saved annual_data/17/MediumOffice/AK/AK_df.csv
# Saved annual_data/17/Outpatient/AK/AK_df.csv
# Saved annual_data/17/PrimarySchool/AK/AK_df.csv
# Saved annual_data/17/QuickServiceRestaurant/AK/AK_df.csv
# Saved annual_data/17/RetailStandalone/AK/AK_df.csv
# Saved annual_data/17/RetailStripmall/AK/AK_df.csv
# Saved annual_data/17/SecondarySchool/AK/AK_df.csv
# Saved annual_data/17/SmallHotel/AK/AK_df.csv
# Saved annual_data/17/SmallOffice/AK/AK_df.csv
# Saved annual_data/17/Warehouse/AK/AK_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=AL/csv/AL_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: AL
# Saved annual_data/17/FullServiceRestaurant/AL/AL_df.csv
# Saved annual_data/17/Hospital/AL/AL_df.csv
# Saved annual_data/17/LargeHotel/AL/AL_df.csv
# Saved annual_data/17/LargeOffice/AL/AL_df.csv
# Saved annual_data/17/MediumOffice/AL/AL_df.csv
# Saved annual_data/17/Outpatient/AL/AL_df.csv
# Saved annual_data/17/PrimarySchool/AL/AL_df.csv
# Saved annual_data/17/QuickServiceRestaurant/AL/AL_df.csv
# Saved annual_data/17/RetailStandalone/AL/AL_df.csv
# Saved annual_data/17/RetailStripmall/AL/AL_df.csv
# Saved annual_data/17/SecondarySchool/AL/AL_df.csv
# Saved annual_data/17/SmallHotel/AL/AL_df.csv
# Saved annual_data/17/SmallOffice/AL/AL_df.csv
# Saved annual_data/17/Warehouse/AL/AL_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=AR/csv/AR_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: AR
# Saved annual_data/17/FullServiceRestaurant/AR/AR_df.csv
# Saved annual_data/17/Hospital/AR/AR_df.csv
# Saved annual_data/17/LargeHotel/AR/AR_df.csv
# Saved annual_data/17/LargeOffice/AR/AR_df.csv
# Saved annual_data/17/MediumOffice/AR/AR_df.csv
# Saved annual_data/17/Outpatient/AR/AR_df.csv
# Saved annual_data/17/PrimarySchool/AR/AR_df.csv
# Saved annual_data/17/QuickServiceRestaurant/AR/AR_df.csv
# Saved annual_data/17/RetailStandalone/AR/AR_df.csv
# Saved annual_data/17/RetailStripmall/AR/AR_df.csv
# Saved annual_data/17/SecondarySchool/AR/AR_df.csv
# Saved annual_data/17/SmallHotel/AR/AR_df.csv
# Saved annual_data/17/SmallOffice/AR/AR_df.csv
# Saved annual_data/17/Warehouse/AR/AR_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=AZ/csv/AZ_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: AZ
# Saved annual_data/17/FullServiceRestaurant/AZ/AZ_df.csv
# Saved annual_data/17/Hospital/AZ/AZ_df.csv
# Saved annual_data/17/LargeHotel/AZ/AZ_df.csv
# Saved annual_data/17/LargeOffice/AZ/AZ_df.csv
# Saved annual_data/17/MediumOffice/AZ/AZ_df.csv
# Saved annual_data/17/Outpatient/AZ/AZ_df.csv
# Saved annual_data/17/PrimarySchool/AZ/AZ_df.csv
# Saved annual_data/17/QuickServiceRestaurant/AZ/AZ_df.csv
# Saved annual_data/17/RetailStandalone/AZ/AZ_df.csv
# Saved annual_data/17/RetailStripmall/AZ/AZ_df.csv
# Saved annual_data/17/SecondarySchool/AZ/AZ_df.csv
# Saved annual_data/17/SmallHotel/AZ/AZ_df.csv
# Saved annual_data/17/SmallOffice/AZ/AZ_df.csv
# Saved annual_data/17/Warehouse/AZ/AZ_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=CA/csv/CA_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: CA
# Saved annual_data/17/FullServiceRestaurant/CA/CA_df.csv
# Saved annual_data/17/Hospital/CA/CA_df.csv
# Saved annual_data/17/LargeHotel/CA/CA_df.csv
# Saved annual_data/17/LargeOffice/CA/CA_df.csv
# Saved annual_data/17/MediumOffice/CA/CA_df.csv
# Saved annual_data/17/Outpatient/CA/CA_df.csv
# Saved annual_data/17/PrimarySchool/CA/CA_df.csv
# Saved annual_data/17/QuickServiceRestaurant/CA/CA_df.csv
# Saved annual_data/17/RetailStandalone/CA/CA_df.csv
# Saved annual_data/17/RetailStripmall/CA/CA_df.csv
# Saved annual_data/17/SecondarySchool/CA/CA_df.csv
# Saved annual_data/17/SmallHotel/CA/CA_df.csv
# Saved annual_data/17/SmallOffice/CA/CA_df.csv
# Saved annual_data/17/Warehouse/CA/CA_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=CO/csv/CO_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: CO
# Saved annual_data/17/FullServiceRestaurant/CO/CO_df.csv
# Saved annual_data/17/Hospital/CO/CO_df.csv
# Saved annual_data/17/LargeHotel/CO/CO_df.csv
# Saved annual_data/17/LargeOffice/CO/CO_df.csv
# Saved annual_data/17/MediumOffice/CO/CO_df.csv
# Saved annual_data/17/Outpatient/CO/CO_df.csv
# Saved annual_data/17/PrimarySchool/CO/CO_df.csv
# Saved annual_data/17/QuickServiceRestaurant/CO/CO_df.csv
# Saved annual_data/17/RetailStandalone/CO/CO_df.csv
# Saved annual_data/17/RetailStripmall/CO/CO_df.csv
# Saved annual_data/17/SecondarySchool/CO/CO_df.csv
# Saved annual_data/17/SmallHotel/CO/CO_df.csv
# Saved annual_data/17/SmallOffice/CO/CO_df.csv
# Saved annual_data/17/Warehouse/CO/CO_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=CT/csv/CT_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: CT
# Saved annual_data/17/FullServiceRestaurant/CT/CT_df.csv
# Saved annual_data/17/Hospital/CT/CT_df.csv
# Saved annual_data/17/LargeHotel/CT/CT_df.csv
# Saved annual_data/17/LargeOffice/CT/CT_df.csv
# Saved annual_data/17/MediumOffice/CT/CT_df.csv
# Saved annual_data/17/Outpatient/CT/CT_df.csv
# Saved annual_data/17/PrimarySchool/CT/CT_df.csv
# Saved annual_data/17/QuickServiceRestaurant/CT/CT_df.csv
# Saved annual_data/17/RetailStandalone/CT/CT_df.csv
# Saved annual_data/17/RetailStripmall/CT/CT_df.csv
# Saved annual_data/17/SecondarySchool/CT/CT_df.csv
# Saved annual_data/17/SmallHotel/CT/CT_df.csv
# Saved annual_data/17/SmallOffice/CT/CT_df.csv
# Saved annual_data/17/Warehouse/CT/CT_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=DC/csv/DC_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: DC
# Saved annual_data/17/FullServiceRestaurant/DC/DC_df.csv
# Saved annual_data/17/Hospital/DC/DC_df.csv
# Saved annual_data/17/LargeHotel/DC/DC_df.csv
# Saved annual_data/17/LargeOffice/DC/DC_df.csv
# Saved annual_data/17/MediumOffice/DC/DC_df.csv
# Saved annual_data/17/Outpatient/DC/DC_df.csv
# Saved annual_data/17/PrimarySchool/DC/DC_df.csv
# Saved annual_data/17/QuickServiceRestaurant/DC/DC_df.csv
# Saved annual_data/17/RetailStandalone/DC/DC_df.csv
# Saved annual_data/17/RetailStripmall/DC/DC_df.csv
# Saved annual_data/17/SecondarySchool/DC/DC_df.csv
# Saved annual_data/17/SmallHotel/DC/DC_df.csv
# Saved annual_data/17/SmallOffice/DC/DC_df.csv
# Saved annual_data/17/Warehouse/DC/DC_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=DE/csv/DE_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: DE
# Saved annual_data/17/FullServiceRestaurant/DE/DE_df.csv
# Saved annual_data/17/LargeHotel/DE/DE_df.csv
# Saved annual_data/17/LargeOffice/DE/DE_df.csv
# Saved annual_data/17/MediumOffice/DE/DE_df.csv
# Saved annual_data/17/Outpatient/DE/DE_df.csv
# Saved annual_data/17/PrimarySchool/DE/DE_df.csv
# Saved annual_data/17/QuickServiceRestaurant/DE/DE_df.csv
# Saved annual_data/17/RetailStandalone/DE/DE_df.csv
# Saved annual_data/17/RetailStripmall/DE/DE_df.csv
# Saved annual_data/17/SecondarySchool/DE/DE_df.csv
# Saved annual_data/17/SmallHotel/DE/DE_df.csv
# Saved annual_data/17/SmallOffice/DE/DE_df.csv
# Saved annual_data/17/Warehouse/DE/DE_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=FL/csv/FL_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: FL
# Saved annual_data/17/FullServiceRestaurant/FL/FL_df.csv
# Saved annual_data/17/Hospital/FL/FL_df.csv
# Saved annual_data/17/LargeHotel/FL/FL_df.csv
# Saved annual_data/17/LargeOffice/FL/FL_df.csv
# Saved annual_data/17/MediumOffice/FL/FL_df.csv
# Saved annual_data/17/Outpatient/FL/FL_df.csv
# Saved annual_data/17/PrimarySchool/FL/FL_df.csv
# Saved annual_data/17/QuickServiceRestaurant/FL/FL_df.csv
# Saved annual_data/17/RetailStandalone/FL/FL_df.csv
# Saved annual_data/17/RetailStripmall/FL/FL_df.csv
# Saved annual_data/17/SecondarySchool/FL/FL_df.csv
# Saved annual_data/17/SmallHotel/FL/FL_df.csv
# Saved annual_data/17/SmallOffice/FL/FL_df.csv
# Saved annual_data/17/Warehouse/FL/FL_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=GA/csv/GA_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: GA
# Saved annual_data/17/FullServiceRestaurant/GA/GA_df.csv
# Saved annual_data/17/Hospital/GA/GA_df.csv
# Saved annual_data/17/LargeHotel/GA/GA_df.csv
# Saved annual_data/17/LargeOffice/GA/GA_df.csv
# Saved annual_data/17/MediumOffice/GA/GA_df.csv
# Saved annual_data/17/Outpatient/GA/GA_df.csv
# Saved annual_data/17/PrimarySchool/GA/GA_df.csv
# Saved annual_data/17/QuickServiceRestaurant/GA/GA_df.csv
# Saved annual_data/17/RetailStandalone/GA/GA_df.csv
# Saved annual_data/17/RetailStripmall/GA/GA_df.csv
# Saved annual_data/17/SecondarySchool/GA/GA_df.csv
# Saved annual_data/17/SmallHotel/GA/GA_df.csv
# Saved annual_data/17/SmallOffice/GA/GA_df.csv
# Saved annual_data/17/Warehouse/GA/GA_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=HI/csv/HI_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: HI
# Saved annual_data/17/FullServiceRestaurant/HI/HI_df.csv
# Saved annual_data/17/Hospital/HI/HI_df.csv
# Saved annual_data/17/LargeHotel/HI/HI_df.csv
# Saved annual_data/17/LargeOffice/HI/HI_df.csv
# Saved annual_data/17/MediumOffice/HI/HI_df.csv
# Saved annual_data/17/Outpatient/HI/HI_df.csv
# Saved annual_data/17/PrimarySchool/HI/HI_df.csv
# Saved annual_data/17/QuickServiceRestaurant/HI/HI_df.csv
# Saved annual_data/17/RetailStandalone/HI/HI_df.csv
# Saved annual_data/17/RetailStripmall/HI/HI_df.csv
# Saved annual_data/17/SecondarySchool/HI/HI_df.csv
# Saved annual_data/17/SmallHotel/HI/HI_df.csv
# Saved annual_data/17/SmallOffice/HI/HI_df.csv
# Saved annual_data/17/Warehouse/HI/HI_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=IA/csv/IA_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: IA
# Saved annual_data/17/FullServiceRestaurant/IA/IA_df.csv
# Saved annual_data/17/Hospital/IA/IA_df.csv
# Saved annual_data/17/LargeHotel/IA/IA_df.csv
# Saved annual_data/17/LargeOffice/IA/IA_df.csv
# Saved annual_data/17/MediumOffice/IA/IA_df.csv
# Saved annual_data/17/Outpatient/IA/IA_df.csv
# Saved annual_data/17/PrimarySchool/IA/IA_df.csv
# Saved annual_data/17/QuickServiceRestaurant/IA/IA_df.csv
# Saved annual_data/17/RetailStandalone/IA/IA_df.csv
# Saved annual_data/17/RetailStripmall/IA/IA_df.csv
# Saved annual_data/17/SecondarySchool/IA/IA_df.csv
# Saved annual_data/17/SmallHotel/IA/IA_df.csv
# Saved annual_data/17/SmallOffice/IA/IA_df.csv
# Saved annual_data/17/Warehouse/IA/IA_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=ID/csv/ID_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: ID
# Saved annual_data/17/FullServiceRestaurant/ID/ID_df.csv
# Saved annual_data/17/Hospital/ID/ID_df.csv
# Saved annual_data/17/LargeHotel/ID/ID_df.csv
# Saved annual_data/17/LargeOffice/ID/ID_df.csv
# Saved annual_data/17/MediumOffice/ID/ID_df.csv
# Saved annual_data/17/Outpatient/ID/ID_df.csv
# Saved annual_data/17/PrimarySchool/ID/ID_df.csv
# Saved annual_data/17/QuickServiceRestaurant/ID/ID_df.csv
# Saved annual_data/17/RetailStandalone/ID/ID_df.csv
# Saved annual_data/17/RetailStripmall/ID/ID_df.csv
# Saved annual_data/17/SecondarySchool/ID/ID_df.csv
# Saved annual_data/17/SmallHotel/ID/ID_df.csv
# Saved annual_data/17/SmallOffice/ID/ID_df.csv
# Saved annual_data/17/Warehouse/ID/ID_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=IL/csv/IL_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: IL
# Saved annual_data/17/FullServiceRestaurant/IL/IL_df.csv
# Saved annual_data/17/Hospital/IL/IL_df.csv
# Saved annual_data/17/LargeHotel/IL/IL_df.csv
# Saved annual_data/17/LargeOffice/IL/IL_df.csv
# Saved annual_data/17/MediumOffice/IL/IL_df.csv
# Saved annual_data/17/Outpatient/IL/IL_df.csv
# Saved annual_data/17/PrimarySchool/IL/IL_df.csv
# Saved annual_data/17/QuickServiceRestaurant/IL/IL_df.csv
# Saved annual_data/17/RetailStandalone/IL/IL_df.csv
# Saved annual_data/17/RetailStripmall/IL/IL_df.csv
# Saved annual_data/17/SecondarySchool/IL/IL_df.csv
# Saved annual_data/17/SmallHotel/IL/IL_df.csv
# Saved annual_data/17/SmallOffice/IL/IL_df.csv
# Saved annual_data/17/Warehouse/IL/IL_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=IN/csv/IN_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: IN
# Saved annual_data/17/FullServiceRestaurant/IN/IN_df.csv
# Saved annual_data/17/Hospital/IN/IN_df.csv
# Saved annual_data/17/LargeHotel/IN/IN_df.csv
# Saved annual_data/17/LargeOffice/IN/IN_df.csv
# Saved annual_data/17/MediumOffice/IN/IN_df.csv
# Saved annual_data/17/Outpatient/IN/IN_df.csv
# Saved annual_data/17/PrimarySchool/IN/IN_df.csv
# Saved annual_data/17/QuickServiceRestaurant/IN/IN_df.csv
# Saved annual_data/17/RetailStandalone/IN/IN_df.csv
# Saved annual_data/17/RetailStripmall/IN/IN_df.csv
# Saved annual_data/17/SecondarySchool/IN/IN_df.csv
# Saved annual_data/17/SmallHotel/IN/IN_df.csv
# Saved annual_data/17/SmallOffice/IN/IN_df.csv
# Saved annual_data/17/Warehouse/IN/IN_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=KS/csv/KS_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: KS
# Saved annual_data/17/FullServiceRestaurant/KS/KS_df.csv
# Saved annual_data/17/Hospital/KS/KS_df.csv
# Saved annual_data/17/LargeHotel/KS/KS_df.csv
# Saved annual_data/17/LargeOffice/KS/KS_df.csv
# Saved annual_data/17/MediumOffice/KS/KS_df.csv
# Saved annual_data/17/Outpatient/KS/KS_df.csv
# Saved annual_data/17/PrimarySchool/KS/KS_df.csv
# Saved annual_data/17/QuickServiceRestaurant/KS/KS_df.csv
# Saved annual_data/17/RetailStandalone/KS/KS_df.csv
# Saved annual_data/17/RetailStripmall/KS/KS_df.csv
# Saved annual_data/17/SecondarySchool/KS/KS_df.csv
# Saved annual_data/17/SmallHotel/KS/KS_df.csv
# Saved annual_data/17/SmallOffice/KS/KS_df.csv
# Saved annual_data/17/Warehouse/KS/KS_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=KY/csv/KY_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: KY
# Saved annual_data/17/FullServiceRestaurant/KY/KY_df.csv
# Saved annual_data/17/Hospital/KY/KY_df.csv
# Saved annual_data/17/LargeHotel/KY/KY_df.csv
# Saved annual_data/17/LargeOffice/KY/KY_df.csv
# Saved annual_data/17/MediumOffice/KY/KY_df.csv
# Saved annual_data/17/Outpatient/KY/KY_df.csv
# Saved annual_data/17/PrimarySchool/KY/KY_df.csv
# Saved annual_data/17/QuickServiceRestaurant/KY/KY_df.csv
# Saved annual_data/17/RetailStandalone/KY/KY_df.csv
# Saved annual_data/17/RetailStripmall/KY/KY_df.csv
# Saved annual_data/17/SecondarySchool/KY/KY_df.csv
# Saved annual_data/17/SmallHotel/KY/KY_df.csv
# Saved annual_data/17/SmallOffice/KY/KY_df.csv
# Saved annual_data/17/Warehouse/KY/KY_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=LA/csv/LA_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: LA
# Saved annual_data/17/FullServiceRestaurant/LA/LA_df.csv
# Saved annual_data/17/Hospital/LA/LA_df.csv
# Saved annual_data/17/LargeHotel/LA/LA_df.csv
# Saved annual_data/17/LargeOffice/LA/LA_df.csv
# Saved annual_data/17/MediumOffice/LA/LA_df.csv
# Saved annual_data/17/Outpatient/LA/LA_df.csv
# Saved annual_data/17/PrimarySchool/LA/LA_df.csv
# Saved annual_data/17/QuickServiceRestaurant/LA/LA_df.csv
# Saved annual_data/17/RetailStandalone/LA/LA_df.csv
# Saved annual_data/17/RetailStripmall/LA/LA_df.csv
# Saved annual_data/17/SecondarySchool/LA/LA_df.csv
# Saved annual_data/17/SmallHotel/LA/LA_df.csv
# Saved annual_data/17/SmallOffice/LA/LA_df.csv
# Saved annual_data/17/Warehouse/LA/LA_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=MA/csv/MA_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: MA
# Saved annual_data/17/FullServiceRestaurant/MA/MA_df.csv
# Saved annual_data/17/Hospital/MA/MA_df.csv
# Saved annual_data/17/LargeHotel/MA/MA_df.csv
# Saved annual_data/17/LargeOffice/MA/MA_df.csv
# Saved annual_data/17/MediumOffice/MA/MA_df.csv
# Saved annual_data/17/Outpatient/MA/MA_df.csv
# Saved annual_data/17/PrimarySchool/MA/MA_df.csv
# Saved annual_data/17/QuickServiceRestaurant/MA/MA_df.csv
# Saved annual_data/17/RetailStandalone/MA/MA_df.csv
# Saved annual_data/17/RetailStripmall/MA/MA_df.csv
# Saved annual_data/17/SecondarySchool/MA/MA_df.csv
# Saved annual_data/17/SmallHotel/MA/MA_df.csv
# Saved annual_data/17/SmallOffice/MA/MA_df.csv
# Saved annual_data/17/Warehouse/MA/MA_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=MD/csv/MD_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: MD
# Saved annual_data/17/FullServiceRestaurant/MD/MD_df.csv
# Saved annual_data/17/Hospital/MD/MD_df.csv
# Saved annual_data/17/LargeHotel/MD/MD_df.csv
# Saved annual_data/17/LargeOffice/MD/MD_df.csv
# Saved annual_data/17/MediumOffice/MD/MD_df.csv
# Saved annual_data/17/Outpatient/MD/MD_df.csv
# Saved annual_data/17/PrimarySchool/MD/MD_df.csv
# Saved annual_data/17/QuickServiceRestaurant/MD/MD_df.csv
# Saved annual_data/17/RetailStandalone/MD/MD_df.csv
# Saved annual_data/17/RetailStripmall/MD/MD_df.csv
# Saved annual_data/17/SecondarySchool/MD/MD_df.csv
# Saved annual_data/17/SmallHotel/MD/MD_df.csv
# Saved annual_data/17/SmallOffice/MD/MD_df.csv
# Saved annual_data/17/Warehouse/MD/MD_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=ME/csv/ME_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: ME
# Saved annual_data/17/FullServiceRestaurant/ME/ME_df.csv
# Saved annual_data/17/Hospital/ME/ME_df.csv
# Saved annual_data/17/LargeHotel/ME/ME_df.csv
# Saved annual_data/17/LargeOffice/ME/ME_df.csv
# Saved annual_data/17/MediumOffice/ME/ME_df.csv
# Saved annual_data/17/Outpatient/ME/ME_df.csv
# Saved annual_data/17/PrimarySchool/ME/ME_df.csv
# Saved annual_data/17/QuickServiceRestaurant/ME/ME_df.csv
# Saved annual_data/17/RetailStandalone/ME/ME_df.csv
# Saved annual_data/17/RetailStripmall/ME/ME_df.csv
# Saved annual_data/17/SecondarySchool/ME/ME_df.csv
# Saved annual_data/17/SmallHotel/ME/ME_df.csv
# Saved annual_data/17/SmallOffice/ME/ME_df.csv
# Saved annual_data/17/Warehouse/ME/ME_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=MI/csv/MI_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: MI
# Saved annual_data/17/FullServiceRestaurant/MI/MI_df.csv
# Saved annual_data/17/Hospital/MI/MI_df.csv
# Saved annual_data/17/LargeHotel/MI/MI_df.csv
# Saved annual_data/17/LargeOffice/MI/MI_df.csv
# Saved annual_data/17/MediumOffice/MI/MI_df.csv
# Saved annual_data/17/Outpatient/MI/MI_df.csv
# Saved annual_data/17/PrimarySchool/MI/MI_df.csv
# Saved annual_data/17/QuickServiceRestaurant/MI/MI_df.csv
# Saved annual_data/17/RetailStandalone/MI/MI_df.csv
# Saved annual_data/17/RetailStripmall/MI/MI_df.csv
# Saved annual_data/17/SecondarySchool/MI/MI_df.csv
# Saved annual_data/17/SmallHotel/MI/MI_df.csv
# Saved annual_data/17/SmallOffice/MI/MI_df.csv
# Saved annual_data/17/Warehouse/MI/MI_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=MN/csv/MN_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: MN
# Saved annual_data/17/FullServiceRestaurant/MN/MN_df.csv
# Saved annual_data/17/Hospital/MN/MN_df.csv
# Saved annual_data/17/LargeHotel/MN/MN_df.csv
# Saved annual_data/17/LargeOffice/MN/MN_df.csv
# Saved annual_data/17/MediumOffice/MN/MN_df.csv
# Saved annual_data/17/Outpatient/MN/MN_df.csv
# Saved annual_data/17/PrimarySchool/MN/MN_df.csv
# Saved annual_data/17/QuickServiceRestaurant/MN/MN_df.csv
# Saved annual_data/17/RetailStandalone/MN/MN_df.csv
# Saved annual_data/17/RetailStripmall/MN/MN_df.csv
# Saved annual_data/17/SecondarySchool/MN/MN_df.csv
# Saved annual_data/17/SmallHotel/MN/MN_df.csv
# Saved annual_data/17/SmallOffice/MN/MN_df.csv
# Saved annual_data/17/Warehouse/MN/MN_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=MO/csv/MO_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: MO
# Saved annual_data/17/FullServiceRestaurant/MO/MO_df.csv
# Saved annual_data/17/Hospital/MO/MO_df.csv
# Saved annual_data/17/LargeHotel/MO/MO_df.csv
# Saved annual_data/17/LargeOffice/MO/MO_df.csv
# Saved annual_data/17/MediumOffice/MO/MO_df.csv
# Saved annual_data/17/Outpatient/MO/MO_df.csv
# Saved annual_data/17/PrimarySchool/MO/MO_df.csv
# Saved annual_data/17/QuickServiceRestaurant/MO/MO_df.csv
# Saved annual_data/17/RetailStandalone/MO/MO_df.csv
# Saved annual_data/17/RetailStripmall/MO/MO_df.csv
# Saved annual_data/17/SecondarySchool/MO/MO_df.csv
# Saved annual_data/17/SmallHotel/MO/MO_df.csv
# Saved annual_data/17/SmallOffice/MO/MO_df.csv
# Saved annual_data/17/Warehouse/MO/MO_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=MS/csv/MS_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: MS
# Saved annual_data/17/FullServiceRestaurant/MS/MS_df.csv
# Saved annual_data/17/Hospital/MS/MS_df.csv
# Saved annual_data/17/LargeHotel/MS/MS_df.csv
# Saved annual_data/17/LargeOffice/MS/MS_df.csv
# Saved annual_data/17/MediumOffice/MS/MS_df.csv
# Saved annual_data/17/Outpatient/MS/MS_df.csv
# Saved annual_data/17/PrimarySchool/MS/MS_df.csv
# Saved annual_data/17/QuickServiceRestaurant/MS/MS_df.csv
# Saved annual_data/17/RetailStandalone/MS/MS_df.csv
# Saved annual_data/17/RetailStripmall/MS/MS_df.csv
# Saved annual_data/17/SecondarySchool/MS/MS_df.csv
# Saved annual_data/17/SmallHotel/MS/MS_df.csv
# Saved annual_data/17/SmallOffice/MS/MS_df.csv
# Saved annual_data/17/Warehouse/MS/MS_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=MT/csv/MT_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: MT
# Saved annual_data/17/FullServiceRestaurant/MT/MT_df.csv
# Saved annual_data/17/Hospital/MT/MT_df.csv
# Saved annual_data/17/LargeHotel/MT/MT_df.csv
# Saved annual_data/17/LargeOffice/MT/MT_df.csv
# Saved annual_data/17/MediumOffice/MT/MT_df.csv
# Saved annual_data/17/Outpatient/MT/MT_df.csv
# Saved annual_data/17/PrimarySchool/MT/MT_df.csv
# Saved annual_data/17/QuickServiceRestaurant/MT/MT_df.csv
# Saved annual_data/17/RetailStandalone/MT/MT_df.csv
# Saved annual_data/17/RetailStripmall/MT/MT_df.csv
# Saved annual_data/17/SecondarySchool/MT/MT_df.csv
# Saved annual_data/17/SmallHotel/MT/MT_df.csv
# Saved annual_data/17/SmallOffice/MT/MT_df.csv
# Saved annual_data/17/Warehouse/MT/MT_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=NC/csv/NC_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: NC
# Saved annual_data/17/FullServiceRestaurant/NC/NC_df.csv
# Saved annual_data/17/Hospital/NC/NC_df.csv
# Saved annual_data/17/LargeHotel/NC/NC_df.csv
# Saved annual_data/17/LargeOffice/NC/NC_df.csv
# Saved annual_data/17/MediumOffice/NC/NC_df.csv
# Saved annual_data/17/Outpatient/NC/NC_df.csv
# Saved annual_data/17/PrimarySchool/NC/NC_df.csv
# Saved annual_data/17/QuickServiceRestaurant/NC/NC_df.csv
# Saved annual_data/17/RetailStandalone/NC/NC_df.csv
# Saved annual_data/17/RetailStripmall/NC/NC_df.csv
# Saved annual_data/17/SecondarySchool/NC/NC_df.csv
# Saved annual_data/17/SmallHotel/NC/NC_df.csv
# Saved annual_data/17/SmallOffice/NC/NC_df.csv
# Saved annual_data/17/Warehouse/NC/NC_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=ND/csv/ND_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: ND
# Saved annual_data/17/FullServiceRestaurant/ND/ND_df.csv
# Saved annual_data/17/Hospital/ND/ND_df.csv
# Saved annual_data/17/LargeHotel/ND/ND_df.csv
# Saved annual_data/17/LargeOffice/ND/ND_df.csv
# Saved annual_data/17/MediumOffice/ND/ND_df.csv
# Saved annual_data/17/Outpatient/ND/ND_df.csv
# Saved annual_data/17/PrimarySchool/ND/ND_df.csv
# Saved annual_data/17/QuickServiceRestaurant/ND/ND_df.csv
# Saved annual_data/17/RetailStandalone/ND/ND_df.csv
# Saved annual_data/17/RetailStripmall/ND/ND_df.csv
# Saved annual_data/17/SecondarySchool/ND/ND_df.csv
# Saved annual_data/17/SmallHotel/ND/ND_df.csv
# Saved annual_data/17/SmallOffice/ND/ND_df.csv
# Saved annual_data/17/Warehouse/ND/ND_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=NE/csv/NE_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: NE
# Saved annual_data/17/FullServiceRestaurant/NE/NE_df.csv
# Saved annual_data/17/Hospital/NE/NE_df.csv
# Saved annual_data/17/LargeHotel/NE/NE_df.csv
# Saved annual_data/17/LargeOffice/NE/NE_df.csv
# Saved annual_data/17/MediumOffice/NE/NE_df.csv
# Saved annual_data/17/Outpatient/NE/NE_df.csv
# Saved annual_data/17/PrimarySchool/NE/NE_df.csv
# Saved annual_data/17/QuickServiceRestaurant/NE/NE_df.csv
# Saved annual_data/17/RetailStandalone/NE/NE_df.csv
# Saved annual_data/17/RetailStripmall/NE/NE_df.csv
# Saved annual_data/17/SecondarySchool/NE/NE_df.csv
# Saved annual_data/17/SmallHotel/NE/NE_df.csv
# Saved annual_data/17/SmallOffice/NE/NE_df.csv
# Saved annual_data/17/Warehouse/NE/NE_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=NH/csv/NH_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: NH
# Saved annual_data/17/FullServiceRestaurant/NH/NH_df.csv
# Saved annual_data/17/Hospital/NH/NH_df.csv
# Saved annual_data/17/LargeHotel/NH/NH_df.csv
# Saved annual_data/17/LargeOffice/NH/NH_df.csv
# Saved annual_data/17/MediumOffice/NH/NH_df.csv
# Saved annual_data/17/Outpatient/NH/NH_df.csv
# Saved annual_data/17/PrimarySchool/NH/NH_df.csv
# Saved annual_data/17/QuickServiceRestaurant/NH/NH_df.csv
# Saved annual_data/17/RetailStandalone/NH/NH_df.csv
# Saved annual_data/17/RetailStripmall/NH/NH_df.csv
# Saved annual_data/17/SecondarySchool/NH/NH_df.csv
# Saved annual_data/17/SmallHotel/NH/NH_df.csv
# Saved annual_data/17/SmallOffice/NH/NH_df.csv
# Saved annual_data/17/Warehouse/NH/NH_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=NJ/csv/NJ_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: NJ
# Saved annual_data/17/FullServiceRestaurant/NJ/NJ_df.csv
# Saved annual_data/17/Hospital/NJ/NJ_df.csv
# Saved annual_data/17/LargeHotel/NJ/NJ_df.csv
# Saved annual_data/17/LargeOffice/NJ/NJ_df.csv
# Saved annual_data/17/MediumOffice/NJ/NJ_df.csv
# Saved annual_data/17/Outpatient/NJ/NJ_df.csv
# Saved annual_data/17/PrimarySchool/NJ/NJ_df.csv
# Saved annual_data/17/QuickServiceRestaurant/NJ/NJ_df.csv
# Saved annual_data/17/RetailStandalone/NJ/NJ_df.csv
# Saved annual_data/17/RetailStripmall/NJ/NJ_df.csv
# Saved annual_data/17/SecondarySchool/NJ/NJ_df.csv
# Saved annual_data/17/SmallHotel/NJ/NJ_df.csv
# Saved annual_data/17/SmallOffice/NJ/NJ_df.csv
# Saved annual_data/17/Warehouse/NJ/NJ_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=NM/csv/NM_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: NM
# Saved annual_data/17/FullServiceRestaurant/NM/NM_df.csv
# Saved annual_data/17/Hospital/NM/NM_df.csv
# Saved annual_data/17/LargeHotel/NM/NM_df.csv
# Saved annual_data/17/LargeOffice/NM/NM_df.csv
# Saved annual_data/17/MediumOffice/NM/NM_df.csv
# Saved annual_data/17/Outpatient/NM/NM_df.csv
# Saved annual_data/17/PrimarySchool/NM/NM_df.csv
# Saved annual_data/17/QuickServiceRestaurant/NM/NM_df.csv
# Saved annual_data/17/RetailStandalone/NM/NM_df.csv
# Saved annual_data/17/RetailStripmall/NM/NM_df.csv
# Saved annual_data/17/SecondarySchool/NM/NM_df.csv
# Saved annual_data/17/SmallHotel/NM/NM_df.csv
# Saved annual_data/17/SmallOffice/NM/NM_df.csv
# Saved annual_data/17/Warehouse/NM/NM_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=NV/csv/NV_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: NV
# Saved annual_data/17/FullServiceRestaurant/NV/NV_df.csv
# Saved annual_data/17/Hospital/NV/NV_df.csv
# Saved annual_data/17/LargeHotel/NV/NV_df.csv
# Saved annual_data/17/LargeOffice/NV/NV_df.csv
# Saved annual_data/17/MediumOffice/NV/NV_df.csv
# Saved annual_data/17/Outpatient/NV/NV_df.csv
# Saved annual_data/17/PrimarySchool/NV/NV_df.csv
# Saved annual_data/17/QuickServiceRestaurant/NV/NV_df.csv
# Saved annual_data/17/RetailStandalone/NV/NV_df.csv
# Saved annual_data/17/RetailStripmall/NV/NV_df.csv
# Saved annual_data/17/SecondarySchool/NV/NV_df.csv
# Saved annual_data/17/SmallHotel/NV/NV_df.csv
# Saved annual_data/17/SmallOffice/NV/NV_df.csv
# Saved annual_data/17/Warehouse/NV/NV_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=NY/csv/NY_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: NY
# Saved annual_data/17/FullServiceRestaurant/NY/NY_df.csv
# Saved annual_data/17/Hospital/NY/NY_df.csv
# Saved annual_data/17/LargeHotel/NY/NY_df.csv
# Saved annual_data/17/LargeOffice/NY/NY_df.csv
# Saved annual_data/17/MediumOffice/NY/NY_df.csv
# Saved annual_data/17/Outpatient/NY/NY_df.csv
# Saved annual_data/17/PrimarySchool/NY/NY_df.csv
# Saved annual_data/17/QuickServiceRestaurant/NY/NY_df.csv
# Saved annual_data/17/RetailStandalone/NY/NY_df.csv
# Saved annual_data/17/RetailStripmall/NY/NY_df.csv
# Saved annual_data/17/SecondarySchool/NY/NY_df.csv
# Saved annual_data/17/SmallHotel/NY/NY_df.csv
# Saved annual_data/17/SmallOffice/NY/NY_df.csv
# Saved annual_data/17/Warehouse/NY/NY_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=OH/csv/OH_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: OH
# Saved annual_data/17/FullServiceRestaurant/OH/OH_df.csv
# Saved annual_data/17/Hospital/OH/OH_df.csv
# Saved annual_data/17/LargeHotel/OH/OH_df.csv
# Saved annual_data/17/LargeOffice/OH/OH_df.csv
# Saved annual_data/17/MediumOffice/OH/OH_df.csv
# Saved annual_data/17/Outpatient/OH/OH_df.csv
# Saved annual_data/17/PrimarySchool/OH/OH_df.csv
# Saved annual_data/17/QuickServiceRestaurant/OH/OH_df.csv
# Saved annual_data/17/RetailStandalone/OH/OH_df.csv
# Saved annual_data/17/RetailStripmall/OH/OH_df.csv
# Saved annual_data/17/SecondarySchool/OH/OH_df.csv
# Saved annual_data/17/SmallHotel/OH/OH_df.csv
# Saved annual_data/17/SmallOffice/OH/OH_df.csv
# Saved annual_data/17/Warehouse/OH/OH_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=OK/csv/OK_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: OK
# Saved annual_data/17/FullServiceRestaurant/OK/OK_df.csv
# Saved annual_data/17/Hospital/OK/OK_df.csv
# Saved annual_data/17/LargeHotel/OK/OK_df.csv
# Saved annual_data/17/LargeOffice/OK/OK_df.csv
# Saved annual_data/17/MediumOffice/OK/OK_df.csv
# Saved annual_data/17/Outpatient/OK/OK_df.csv
# Saved annual_data/17/PrimarySchool/OK/OK_df.csv
# Saved annual_data/17/QuickServiceRestaurant/OK/OK_df.csv
# Saved annual_data/17/RetailStandalone/OK/OK_df.csv
# Saved annual_data/17/RetailStripmall/OK/OK_df.csv
# Saved annual_data/17/SecondarySchool/OK/OK_df.csv
# Saved annual_data/17/SmallHotel/OK/OK_df.csv
# Saved annual_data/17/SmallOffice/OK/OK_df.csv
# Saved annual_data/17/Warehouse/OK/OK_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=OR/csv/OR_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: OR
# Saved annual_data/17/FullServiceRestaurant/OR/OR_df.csv
# Saved annual_data/17/Hospital/OR/OR_df.csv
# Saved annual_data/17/LargeHotel/OR/OR_df.csv
# Saved annual_data/17/LargeOffice/OR/OR_df.csv
# Saved annual_data/17/MediumOffice/OR/OR_df.csv
# Saved annual_data/17/Outpatient/OR/OR_df.csv
# Saved annual_data/17/PrimarySchool/OR/OR_df.csv
# Saved annual_data/17/QuickServiceRestaurant/OR/OR_df.csv
# Saved annual_data/17/RetailStandalone/OR/OR_df.csv
# Saved annual_data/17/RetailStripmall/OR/OR_df.csv
# Saved annual_data/17/SecondarySchool/OR/OR_df.csv
# Saved annual_data/17/SmallHotel/OR/OR_df.csv
# Saved annual_data/17/SmallOffice/OR/OR_df.csv
# Saved annual_data/17/Warehouse/OR/OR_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=PA/csv/PA_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: PA
# Saved annual_data/17/FullServiceRestaurant/PA/PA_df.csv
# Saved annual_data/17/Hospital/PA/PA_df.csv
# Saved annual_data/17/LargeHotel/PA/PA_df.csv
# Saved annual_data/17/LargeOffice/PA/PA_df.csv
# Saved annual_data/17/MediumOffice/PA/PA_df.csv
# Saved annual_data/17/Outpatient/PA/PA_df.csv
# Saved annual_data/17/PrimarySchool/PA/PA_df.csv
# Saved annual_data/17/QuickServiceRestaurant/PA/PA_df.csv
# Saved annual_data/17/RetailStandalone/PA/PA_df.csv
# Saved annual_data/17/RetailStripmall/PA/PA_df.csv
# Saved annual_data/17/SecondarySchool/PA/PA_df.csv
# Saved annual_data/17/SmallHotel/PA/PA_df.csv
# Saved annual_data/17/SmallOffice/PA/PA_df.csv
# Saved annual_data/17/Warehouse/PA/PA_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=RI/csv/RI_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: RI
# Saved annual_data/17/FullServiceRestaurant/RI/RI_df.csv
# Saved annual_data/17/Hospital/RI/RI_df.csv
# Saved annual_data/17/LargeHotel/RI/RI_df.csv
# Saved annual_data/17/LargeOffice/RI/RI_df.csv
# Saved annual_data/17/MediumOffice/RI/RI_df.csv
# Saved annual_data/17/Outpatient/RI/RI_df.csv
# Saved annual_data/17/PrimarySchool/RI/RI_df.csv
# Saved annual_data/17/QuickServiceRestaurant/RI/RI_df.csv
# Saved annual_data/17/RetailStandalone/RI/RI_df.csv
# Saved annual_data/17/RetailStripmall/RI/RI_df.csv
# Saved annual_data/17/SecondarySchool/RI/RI_df.csv
# Saved annual_data/17/SmallHotel/RI/RI_df.csv
# Saved annual_data/17/SmallOffice/RI/RI_df.csv
# Saved annual_data/17/Warehouse/RI/RI_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=SC/csv/SC_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: SC
# Saved annual_data/17/FullServiceRestaurant/SC/SC_df.csv
# Saved annual_data/17/Hospital/SC/SC_df.csv
# Saved annual_data/17/LargeHotel/SC/SC_df.csv
# Saved annual_data/17/LargeOffice/SC/SC_df.csv
# Saved annual_data/17/MediumOffice/SC/SC_df.csv
# Saved annual_data/17/Outpatient/SC/SC_df.csv
# Saved annual_data/17/PrimarySchool/SC/SC_df.csv
# Saved annual_data/17/QuickServiceRestaurant/SC/SC_df.csv
# Saved annual_data/17/RetailStandalone/SC/SC_df.csv
# Saved annual_data/17/RetailStripmall/SC/SC_df.csv
# Saved annual_data/17/SecondarySchool/SC/SC_df.csv
# Saved annual_data/17/SmallHotel/SC/SC_df.csv
# Saved annual_data/17/SmallOffice/SC/SC_df.csv
# Saved annual_data/17/Warehouse/SC/SC_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=SD/csv/SD_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: SD
# Saved annual_data/17/FullServiceRestaurant/SD/SD_df.csv
# Saved annual_data/17/Hospital/SD/SD_df.csv
# Saved annual_data/17/LargeHotel/SD/SD_df.csv
# Saved annual_data/17/LargeOffice/SD/SD_df.csv
# Saved annual_data/17/MediumOffice/SD/SD_df.csv
# Saved annual_data/17/Outpatient/SD/SD_df.csv
# Saved annual_data/17/PrimarySchool/SD/SD_df.csv
# Saved annual_data/17/QuickServiceRestaurant/SD/SD_df.csv
# Saved annual_data/17/RetailStandalone/SD/SD_df.csv
# Saved annual_data/17/RetailStripmall/SD/SD_df.csv
# Saved annual_data/17/SecondarySchool/SD/SD_df.csv
# Saved annual_data/17/SmallHotel/SD/SD_df.csv
# Saved annual_data/17/SmallOffice/SD/SD_df.csv
# Saved annual_data/17/Warehouse/SD/SD_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=TN/csv/TN_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: TN
# Saved annual_data/17/FullServiceRestaurant/TN/TN_df.csv
# Saved annual_data/17/Hospital/TN/TN_df.csv
# Saved annual_data/17/LargeHotel/TN/TN_df.csv
# Saved annual_data/17/LargeOffice/TN/TN_df.csv
# Saved annual_data/17/MediumOffice/TN/TN_df.csv
# Saved annual_data/17/Outpatient/TN/TN_df.csv
# Saved annual_data/17/PrimarySchool/TN/TN_df.csv
# Saved annual_data/17/QuickServiceRestaurant/TN/TN_df.csv
# Saved annual_data/17/RetailStandalone/TN/TN_df.csv
# Saved annual_data/17/RetailStripmall/TN/TN_df.csv
# Saved annual_data/17/SecondarySchool/TN/TN_df.csv
# Saved annual_data/17/SmallHotel/TN/TN_df.csv
# Saved annual_data/17/SmallOffice/TN/TN_df.csv
# Saved annual_data/17/Warehouse/TN/TN_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=TX/csv/TX_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: TX
# Saved annual_data/17/FullServiceRestaurant/TX/TX_df.csv
# Saved annual_data/17/Hospital/TX/TX_df.csv
# Saved annual_data/17/LargeHotel/TX/TX_df.csv
# Saved annual_data/17/LargeOffice/TX/TX_df.csv
# Saved annual_data/17/MediumOffice/TX/TX_df.csv
# Saved annual_data/17/Outpatient/TX/TX_df.csv
# Saved annual_data/17/PrimarySchool/TX/TX_df.csv
# Saved annual_data/17/QuickServiceRestaurant/TX/TX_df.csv
# Saved annual_data/17/RetailStandalone/TX/TX_df.csv
# Saved annual_data/17/RetailStripmall/TX/TX_df.csv
# Saved annual_data/17/SecondarySchool/TX/TX_df.csv
# Saved annual_data/17/SmallHotel/TX/TX_df.csv
# Saved annual_data/17/SmallOffice/TX/TX_df.csv
# Saved annual_data/17/Warehouse/TX/TX_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=UT/csv/UT_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: UT
# Saved annual_data/17/FullServiceRestaurant/UT/UT_df.csv
# Saved annual_data/17/Hospital/UT/UT_df.csv
# Saved annual_data/17/LargeHotel/UT/UT_df.csv
# Saved annual_data/17/LargeOffice/UT/UT_df.csv
# Saved annual_data/17/MediumOffice/UT/UT_df.csv
# Saved annual_data/17/Outpatient/UT/UT_df.csv
# Saved annual_data/17/PrimarySchool/UT/UT_df.csv
# Saved annual_data/17/QuickServiceRestaurant/UT/UT_df.csv
# Saved annual_data/17/RetailStandalone/UT/UT_df.csv
# Saved annual_data/17/RetailStripmall/UT/UT_df.csv
# Saved annual_data/17/SecondarySchool/UT/UT_df.csv
# Saved annual_data/17/SmallHotel/UT/UT_df.csv
# Saved annual_data/17/SmallOffice/UT/UT_df.csv
# Saved annual_data/17/Warehouse/UT/UT_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=VA/csv/VA_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: VA
# Saved annual_data/17/FullServiceRestaurant/VA/VA_df.csv
# Saved annual_data/17/Hospital/VA/VA_df.csv
# Saved annual_data/17/LargeHotel/VA/VA_df.csv
# Saved annual_data/17/LargeOffice/VA/VA_df.csv
# Saved annual_data/17/MediumOffice/VA/VA_df.csv
# Saved annual_data/17/Outpatient/VA/VA_df.csv
# Saved annual_data/17/PrimarySchool/VA/VA_df.csv
# Saved annual_data/17/QuickServiceRestaurant/VA/VA_df.csv
# Saved annual_data/17/RetailStandalone/VA/VA_df.csv
# Saved annual_data/17/RetailStripmall/VA/VA_df.csv
# Saved annual_data/17/SecondarySchool/VA/VA_df.csv
# Saved annual_data/17/SmallHotel/VA/VA_df.csv
# Saved annual_data/17/SmallOffice/VA/VA_df.csv
# Saved annual_data/17/Warehouse/VA/VA_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=VT/csv/VT_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: VT
# Saved annual_data/17/FullServiceRestaurant/VT/VT_df.csv
# Saved annual_data/17/Hospital/VT/VT_df.csv
# Saved annual_data/17/LargeHotel/VT/VT_df.csv
# Saved annual_data/17/LargeOffice/VT/VT_df.csv
# Saved annual_data/17/MediumOffice/VT/VT_df.csv
# Saved annual_data/17/Outpatient/VT/VT_df.csv
# Saved annual_data/17/PrimarySchool/VT/VT_df.csv
# Saved annual_data/17/QuickServiceRestaurant/VT/VT_df.csv
# Saved annual_data/17/RetailStandalone/VT/VT_df.csv
# Saved annual_data/17/RetailStripmall/VT/VT_df.csv
# Saved annual_data/17/SecondarySchool/VT/VT_df.csv
# Saved annual_data/17/SmallHotel/VT/VT_df.csv
# Saved annual_data/17/SmallOffice/VT/VT_df.csv
# Saved annual_data/17/Warehouse/VT/VT_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=WA/csv/WA_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: WA
# Saved annual_data/17/FullServiceRestaurant/WA/WA_df.csv
# Saved annual_data/17/Hospital/WA/WA_df.csv
# Saved annual_data/17/LargeHotel/WA/WA_df.csv
# Saved annual_data/17/LargeOffice/WA/WA_df.csv
# Saved annual_data/17/MediumOffice/WA/WA_df.csv
# Saved annual_data/17/Outpatient/WA/WA_df.csv
# Saved annual_data/17/PrimarySchool/WA/WA_df.csv
# Saved annual_data/17/QuickServiceRestaurant/WA/WA_df.csv
# Saved annual_data/17/RetailStandalone/WA/WA_df.csv
# Saved annual_data/17/RetailStripmall/WA/WA_df.csv
# Saved annual_data/17/SecondarySchool/WA/WA_df.csv
# Saved annual_data/17/SmallHotel/WA/WA_df.csv
# Saved annual_data/17/SmallOffice/WA/WA_df.csv
# Saved annual_data/17/Warehouse/WA/WA_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=WI/csv/WI_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: WI
# Saved annual_data/17/FullServiceRestaurant/WI/WI_df.csv
# Saved annual_data/17/Hospital/WI/WI_df.csv
# Saved annual_data/17/LargeHotel/WI/WI_df.csv
# Saved annual_data/17/LargeOffice/WI/WI_df.csv
# Saved annual_data/17/MediumOffice/WI/WI_df.csv
# Saved annual_data/17/Outpatient/WI/WI_df.csv
# Saved annual_data/17/PrimarySchool/WI/WI_df.csv
# Saved annual_data/17/QuickServiceRestaurant/WI/WI_df.csv
# Saved annual_data/17/RetailStandalone/WI/WI_df.csv
# Saved annual_data/17/RetailStripmall/WI/WI_df.csv
# Saved annual_data/17/SecondarySchool/WI/WI_df.csv
# Saved annual_data/17/SmallHotel/WI/WI_df.csv
# Saved annual_data/17/SmallOffice/WI/WI_df.csv
# Saved annual_data/17/Warehouse/WI/WI_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=WV/csv/WV_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: WV
# Saved annual_data/17/FullServiceRestaurant/WV/WV_df.csv
# Saved annual_data/17/Hospital/WV/WV_df.csv
# Saved annual_data/17/LargeHotel/WV/WV_df.csv
# Saved annual_data/17/LargeOffice/WV/WV_df.csv
# Saved annual_data/17/MediumOffice/WV/WV_df.csv
# Saved annual_data/17/Outpatient/WV/WV_df.csv
# Saved annual_data/17/PrimarySchool/WV/WV_df.csv
# Saved annual_data/17/QuickServiceRestaurant/WV/WV_df.csv
# Saved annual_data/17/RetailStandalone/WV/WV_df.csv
# Saved annual_data/17/RetailStripmall/WV/WV_df.csv
# Saved annual_data/17/SecondarySchool/WV/WV_df.csv
# Saved annual_data/17/SmallHotel/WV/WV_df.csv
# Saved annual_data/17/SmallOffice/WV/WV_df.csv
# Saved annual_data/17/Warehouse/WV/WV_df.csv
# url: https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2023/comstock_amy2018_release_2/metadata_and_annual_results/by_state/state=WY/csv/WY_upgrade17_metadata_and_annual_results.csv
# DOWNLOADING upgrade: 17, state: WY
# Saved annual_data/17/FullServiceRestaurant/WY/WY_df.csv
# Saved annual_data/17/Hospital/WY/WY_df.csv
# Saved annual_data/17/LargeHotel/WY/WY_df.csv
# Saved annual_data/17/LargeOffice/WY/WY_df.csv
# Saved annual_data/17/MediumOffice/WY/WY_df.csv
# Saved annual_data/17/Outpatient/WY/WY_df.csv
# Saved annual_data/17/PrimarySchool/WY/WY_df.csv
# Saved annual_data/17/QuickServiceRestaurant/WY/WY_df.csv
# Saved annual_data/17/RetailStandalone/WY/WY_df.csv
# Saved annual_data/17/RetailStripmall/WY/WY_df.csv
# Saved annual_data/17/SecondarySchool/WY/WY_df.csv
# Saved annual_data/17/SmallHotel/WY/WY_df.csv
# Saved annual_data/17/SmallOffice/WY/WY_df.csv
# Saved annual_data/17/Warehouse/WY/WY_df.csv
